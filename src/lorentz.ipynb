# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 28.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # Derivatives

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.draw()
plt.show()
# Out:
# C:\Users\theod\AppData\Local\Temp/ipykernel_18872/2632057571.py:20: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")

# %%
rho = 28.0
sigma = 10.
beta = 3.7

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # Derivatives

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
ax.set_ylabel("y")
ax.set_xlabel("x")
ax.set_zlabel("z")
plt.plot(1,1,1, "o", c="red", label="start state")
plt.legend()
proj_dir = r'C:\\Users\\theod\\Desktop\\UCL\\Machine Learning\\Project'
import os
# plt.savefig(os.path.join(proj_dir, "overleaf images", "lorentz2.png"), dpi=100, bbox_inches="tight")

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\\Users\\theod\\Desktop\\UCL\\Machine Learning\\Project\\all runs.csv')

# %%
df.columns
# Out:
# Index(['Name', 'Created', 'Runtime', 'Group', 'End Time', 'Hostname',
#        'Job Type', 'ID', 'Notes', 'State', 'Updated', 'Tags', 'actor_decay',
#        'alpha', 'batch_size', 'beta', 'buffer_size', 'clip', 'critic_decay',
#        'decay_number', 'discount', 'dt', 'epsilon', 'labda', 'lamda',
#        'learning_rate', 'lr', 'lr_actor', 'lr_critic', 'max_episodes',
#        'max_epochs', 'max_grad_norm', 'online_updating', 'random_experience',
#        'reward_type', 'rho', 'scheduler', 'seed', 'tau', 'data.episodes',
#        'data.final_point', 'data.frame_idx', 'data.moving_avg_rewards',
#        'data.moving_std_rewards', 'data.rewards', 'episode_reward', 'episodes',
#        'final_point', 'frame_idx', 'loss', 'mean_reward', 'moving_average',
#        'moving_avg_rewards', 'moving_std_rewards', 'pol_loss', 'rewards',
#        'success_rate', 'top_reward', 'val_loss'],
#       dtype='object')

# %%
df1 = df[["Group", "Job Type", "mean_reward", "success_rate", "seed"]]

# %%
df2 = df1.dropna(axis=0)

# %%
df0 = df2[df2["Group"]=="Noisy"]

# %%
import numpy as np

# %%
np.std([0.5123, 0.5207, 0.4437])
# Out:
# 0.034489160938216856

# %%
alg = "DQN"

# %%
df0[df2["Job Type"]==alg]["success_rate"].std(), df0[df2["Job Type"]==alg]["success_rate"].shape
# Out:
# C:\Users\theod\AppData\Local\Temp/ipykernel_18872/3694835695.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df0[df2["Job Type"]==alg]["success_rate"].std(), df0[df2["Job Type"]==alg]["success_rate"].shape
# (0.005892556509887954, (2,))
